# %% [markdown]
# # Data Cleaning

# %% [markdown]
# <b>BUT</b> less messy, more organized, and finalized.
# Since the first data cleaning file includes exploration of each data, it is definitely hard to catch what will I really do. However, this notebook aims to provide you the data that we are going to mainly use in the project. :)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
